# %% [markdown]
# # constant tensors and variables

# %%
import tensorflow as tf
x = tf.ones(shape=(2, 1))
print(x)

x = tf.zeros(shape=(2,1))
print(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import tensorflow as tf
#       2 x = tf.ones(shape=(2, 1))
#       3 print(x)
#
# File c:\Users\ryanz\faculdade\dl\DeepLearningWithPython\env\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File c:\Users\ryanz\faculdade\dl\DeepLearningWithPython\env\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
# ...
